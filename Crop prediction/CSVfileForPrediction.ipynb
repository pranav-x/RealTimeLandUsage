# %%
from numpy import array
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
import numpy as np
import pandas as pd
import seaborn as sns  
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline
import pickle
from keras.layers import Bidirectional

# %%
arr1=[]
a = pd.read_csv("/content/drive/My Drive/data for prediction/Humidity/HumidityPreProc2015.csv",header=None)
b = pd.read_csv("/content/drive/My Drive/data for prediction/ndvi/NDVIPreProcessed2015.csv",header=None)
c = pd.read_csv("/content/drive/My Drive/data for prediction/soil/SoilMoiPreProcessed2015.csv",header=None)
d = pd.read_csv("/content/drive/My Drive/data for prediction/temperature/TemperaturePreProcessed2015.csv",header=None)

a = a.iloc[:,9:13].mean(axis=1)
b = b.iloc[:,4:6].mean(axis=1)
c = c.iloc[:,9:13].mean(axis=1)
d = d.iloc[:,9:13].mean(axis=1)

a = a.mean(axis=0)
b = b.mean(axis=0)
c = c.mean(axis=0)
d = d.mean(axis=0)



arr1.append(a)
arr1.append(b)
arr1.append(c)
arr1.append(d)

arr2=[]
a = pd.read_csv("/content/drive/My Drive/data for prediction/Humidity/HumidityPreProc2016.csv",header=None)
b = pd.read_csv("/content/drive/My Drive/data for prediction/ndvi/NDVIPreProcessed2016.csv",header=None)
c = pd.read_csv("/content/drive/My Drive/data for prediction/soil/SoilMoiPreProcessed2016.csv",header=None)
d = pd.read_csv("/content/drive/My Drive/data for prediction/temperature/TemperaturePreProcessed2016.csv",header=None)

a = a.iloc[:,9:13].mean(axis=1)
b = b.iloc[:,4:6].mean(axis=1)
c = c.iloc[:,9:13].mean(axis=1)
d = d.iloc[:,9:13].mean(axis=1)

a = a.mean(axis=0)
b = b.mean(axis=0)
c = c.mean(axis=0)
d = d.mean(axis=0)



arr2.append(a)
arr2.append(b)
arr2.append(c)
arr2.append(d)

arr3=[]
a = pd.read_csv("/content/drive/My Drive/data for prediction/Humidity/HumidityPreProc2017.csv",header=None)
b = pd.read_csv("/content/drive/My Drive/data for prediction/ndvi/NDVIPreProcessed2017.csv",header=None)
c = pd.read_csv("/content/drive/My Drive/data for prediction/soil/SoilMoiPreProcessed2017.csv",header=None)
d = pd.read_csv("/content/drive/My Drive/data for prediction/temperature/TemperaturePreProcessed2017.csv",header=None)

a = a.iloc[:,9:13].mean(axis=1)
b = b.iloc[:,4:6].mean(axis=1)
c = c.iloc[:,9:13].mean(axis=1)
d = d.iloc[:,9:13].mean(axis=1)

a = a.mean(axis=0)
b = b.mean(axis=0)
c = c.mean(axis=0)
d = d.mean(axis=0)



arr3.append(a)
arr3.append(b)
arr3.append(c)
arr3.append(d)


arr4=[]
a = pd.read_csv("/content/drive/My Drive/data for prediction/Humidity/HumidityPreProc2018.csv",header=None)
b = pd.read_csv("/content/drive/My Drive/data for prediction/ndvi/NDVIPreProcessed2018.csv",header=None)
c = pd.read_csv("/content/drive/My Drive/data for prediction/soil/SoilMoiPreProcessed2018.csv",header=None)
d = pd.read_csv("/content/drive/My Drive/data for prediction/temperature/TemperaturePreProcessed2018.csv",header=None)

a = a.iloc[:,9:13].mean(axis=1)
b = b.iloc[:,4:6].mean(axis=1)
c = c.iloc[:,9:13].mean(axis=1)
d = d.iloc[:,9:13].mean(axis=1)

a = a.mean(axis=0)
b = b.mean(axis=0)
c = c.mean(axis=0)
d = d.mean(axis=0)



arr4.append(a)
arr4.append(b)
arr4.append(c)
arr4.append(d)


df = pd.DataFrame([arr1,arr2,arr3,arr4])

df.to_csv (r'/content/drive/My Drive/data for prediction/TrainingData.csv', index = False, header=False)

# %%
arr5=[]
a = pd.read_csv("/content/drive/My Drive/data for prediction/Humidity/HumidityPreProc2019.csv",header=None)
b = pd.read_csv("/content/drive/My Drive/data for prediction/ndvi/NDVIPreProcessed2019.csv",header=None)
c = pd.read_csv("/content/drive/My Drive/data for prediction/soil/SoilMoiPreProcessed2019.csv",header=None)
d = pd.read_csv("/content/drive/My Drive/data for prediction/temperature/TemperaturePreProcessed2019.csv",header=None)

a = a.iloc[:,9:13].mean(axis=1)
b = b.iloc[:,4:6].mean(axis=1)
c = c.iloc[:,9:13].mean(axis=1)
d = d.iloc[:,9:13].mean(axis=1)

a = a.mean(axis=0)
b = b.mean(axis=0)
c = c.mean(axis=0)
d = d.mean(axis=0)



arr5.append(a)
arr5.append(b)
arr5.append(c)
arr5.append(d)

df = pd.DataFrame([arr5])
df.to_csv (r'/content/drive/My Drive/data for prediction/TrainingDataY.csv', index = False, header=False)
